# %%
from pptx import Presentation

def create_swot_presentation():
    presentation = Presentation()

    slides_data = [
        {"title": "SWOT аналіз", "layout": 0},
        {"title": "План доповіді", "layout": 1, "points": [
            "Що таке SWOT аналіз?",
            "Як провести SWOT аналіз?",
            "Приклади застосування SWOT аналізу"
        ]},
        {"title": "SWOT аналіз: Опортуніті", "layout": 1, "points": [
            "Виявлення можливостей розвитку",
            "Пошук нових ринків",
            "Створення конкурентних переваг"
        ]},
        {"title": "SWOT аналіз: Сильні сторони", "layout": 1, "points": [
            "Унікальні продукти або послуги",
            "Сильний бренд",
            "Доступ до ключових ресурсів"
        ]},
        {"title": "SWOT аналіз: Слабкі сторони", "layout": 1, "points": [
            "Високі витрати на виробництво",
            "Низька ефективність маркетингу",
            "Нестабільність управління"
        ]},
        {"title": "SWOT аналіз: Загрози", "layout": 1, "points": [
            "Зміни в законодавстві",
            "Конкуренція на ринку",
            "Технологічні зміни"
        ]},
        {"title": "Дякую за увагу!", "layout": 0},
        {"title": "SWOT аналіз: Визначення", "layout": 2, "subtitle": "Загальний опис SWOT аналізу"},
        {"title": "SWOT аналіз: Три колонки", "layout": 3, "points": [
            "Слабкі сторони",
            "Сильні сторони",
            "Загрози",
            "Опортуніті"
        ]},
        {"title": "SWOT аналіз: Заголовок", "layout": 4},
        {"title": "SWOT аналіз: Роздільник", "layout": 5},
        {"title": "SWOT аналіз: Порожній слайд", "layout": 6}
    ]

    for slide_data in slides_data:
        slide_layout = presentation.slide_layouts[slide_data["layout"]]
        slide = presentation.slides.add_slide(slide_layout)
        title_shape = slide.shapes.title
        title_shape.text = slide_data["title"]
        
        if "points" in slide_data:
            content_shape = slide.placeholders[1]
            content_text = content_shape.text_frame
            for point in slide_data["points"]:
                content_text.add_paragraph().text = point
        
        if "subtitle" in slide_data:
            subtitle_shape = slide.placeholders[1]
            subtitle_shape.text = slide_data["subtitle"]

    presentation.save("SWOT_Analysis_Presentation.pptx")

if __name__ == "__main__":
    create_swot_presentation()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\mykro\OneDrive\Документи\Science\Conf 12apr24\PPtxCreate.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mykro/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8/Science/Conf%2012apr24/PPtxCreate.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from pptx import Presentation
#       <a href='vscode-notebook-cell:/c%3A/Users/mykro/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8/Science/Conf%2012apr24/PPtxCreate.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> def create_swot_presentation():
#       <a href='vscode-notebook-cell:/c%3A/Users/mykro/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8/Science/Conf%2012apr24/PPtxCreate.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>     presentation = Presentation()
#
# ImportError: cannot import name 'Presentation' from 'pptx' (unknown location)

# %%
# %pip install python-pptx
# Out:
# ...
#      -------------------------------------- 471.6/471.6 kB 4.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 159.9/159.9 kB 9.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pptx import Presentation

def create_swot_presentation():
    presentation = Presentation()

    slides_data = [
        {"title": "SWOT аналіз", "layout": 0},
        {"title": "План доповіді", "layout": 1, "points": [
            "Що таке SWOT аналіз?",
            "Як провести SWOT аналіз?",
            "Приклади застосування SWOT аналізу"
        ]},
        {"title": "SWOT аналіз: Опортуніті", "layout": 1, "points": [
            "Виявлення можливостей розвитку",
            "Пошук нових ринків",
            "Створення конкурентних переваг"
        ]},
        {"title": "SWOT аналіз: Сильні сторони", "layout": 1, "points": [
            "Унікальні продукти або послуги",
            "Сильний бренд",
            "Доступ до ключових ресурсів"
        ]},
        {"title": "SWOT аналіз: Слабкі сторони", "layout": 1, "points": [
            "Високі витрати на виробництво",
            "Низька ефективність маркетингу",
            "Нестабільність управління"
        ]},
        {"title": "SWOT аналіз: Загрози", "layout": 1, "points": [
            "Зміни в законодавстві",
            "Конкуренція на ринку",
            "Технологічні зміни"
        ]},
        {"title": "Дякую за увагу!", "layout": 0},
        {"title": "SWOT аналіз: Визначення", "layout": 2, "subtitle": "Загальний опис SWOT аналізу"},
        {"title": "SWOT аналіз: Три колонки", "layout": 3, "points": [
            "Слабкі сторони",
            "Сильні сторони",
            "Загрози",
            "Опортуніті"
        ]},
        {"title": "SWOT аналіз: Заголовок", "layout": 4},
        {"title": "SWOT аналіз: Роздільник", "layout": 5},
        {"title": "SWOT аналіз: Порожній слайд", "layout": 6}
    ]

    for slide_data in slides_data:
        slide_layout = presentation.slide_layouts[slide_data["layout"]]
        slide = presentation.slides.add_slide(slide_layout)
        title_shape = slide.shapes.title
        title_shape.text = slide_data["title"]
        
        if "points" in slide_data:
            content_shape = slide.placeholders[1]
            content_text = content_shape.text_frame
            for point in slide_data["points"]:
                content_text.add_paragraph().text = point
        
        if "subtitle" in slide_data:
            subtitle_shape = slide.placeholders[1]
            subtitle_shape.text = slide_data["subtitle"]

    presentation.save("SWOT_Analysis_Presentation.pptx")

if __name__ == "__main__":
    create_swot_presentation()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mykro\OneDrive\Документи\Science\Conf 12apr24\PPtxCreate.ipynb Cell 3 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/mykro/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8/Science/Conf%2012apr24/PPtxCreate.ipynb#W2sZmlsZQ%3D%3D?line=61'>62</a>     presentation.save("SWOT_Analysis_Presentation.pptx")
#      <a href='vscode-notebook-cell:/c%3A/Users/mykro/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8/Science/Conf%2012apr24/PPtxCreate.ipynb#W2sZmlsZQ%3D%3D?line=63'>64</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mykro/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8/Science/Conf%2012apr24/PPtxCreate.ipynb#W2sZmlsZQ%3D%3D?line=64'>65</a>     create_swot_presentation()
#
# ...

# %%
from pptx import Presentation

def create_swot_presentation():
    presentation = Presentation()

    slides_data = [
        {"title": "SWOT аналіз", "layout": 0},
        {"title": "План доповіді", "layout": 1, "points": [
            "Що таке SWOT аналіз?",
            "Як провести SWOT аналіз?",
            "Приклади застосування SWOT аналізу"
        ]},
        {"title": "SWOT аналіз: Опортуніті", "layout": 1, "points": [
            "Виявлення можливостей розвитку",
            "Пошук нових ринків",
            "Створення конкурентних переваг"
        ]},
        {"title": "SWOT аналіз: Сильні сторони", "layout": 1, "points": [
            "Унікальні продукти або послуги",
            "Сильний бренд",
            "Доступ до ключових ресурсів"
        ]},
        {"title": "SWOT аналіз: Слабкі сторони", "layout": 1, "points": [
            "Високі витрати на виробництво",
            "Низька ефективність маркетингу",
            "Нестабільність управління"
        ]},
        {"title": "SWOT аналіз: Загрози", "layout": 1, "points": [
            "Зміни в законодавстві",
            "Конкуренція на ринку",
            "Технологічні зміни"
        ]},
        {"title": "Дякую за увагу!", "layout": 0},
        {"title": "SWOT аналіз: Визначення", "layout": 2, "subtitle": "Загальний опис SWOT аналізу"},
        {"title": "SWOT аналіз: Три колонки", "layout": 3, "points": [
            "Слабкі сторони",
            "Сильні сторони",
            "Загрози",
            "Опортуніті"
        ]},
        {"title": "SWOT аналіз: Заголовок", "layout": 4},
        {"title": "SWOT аналіз: Роздільник", "layout": 5},
        {"title": "SWOT аналіз: Порожній слайд", "layout": 6}
    ]

    for slide_data in slides_data:
        slide_layout = presentation.slide_layouts[slide_data["layout"]]
        slide = presentation.slides.add_slide(slide_layout)
        
        title_shape = slide.shapes.title
        if title_shape is not None:
            title_shape.text = slide_data["title"]
        else:
            print(f"No title placeholder found for slide with layout {slide_data['layout']}")

        if "points" in slide_data:
            content_shape = slide.placeholders[1]
            content_text = content_shape.text_frame
            if content_text is not None:
                for point in slide_data["points"]:
                    content_text.add_paragraph().text = point
            else:
                print(f"No content placeholder found for slide with layout {slide_data['layout']}")

        if "subtitle" in slide_data:
            subtitle_shape = slide.placeholders[1]
            if subtitle_shape is not None:
                subtitle_shape.text = slide_data["subtitle"]
            else:
                print(f"No content placeholder found for slide with layout {slide_data['layout']}")

    presentation.save("SWOT_Analysis_Presentation.pptx")

if __name__ == "__main__":
    create_swot_presentation()
# Out:
# No title placeholder found for slide with layout 6
